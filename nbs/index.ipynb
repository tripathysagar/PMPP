# %%
#| hide
from PMPP.core import *

# %% [markdown]
# # PMPP Blog
#
# > Learning Programming Massively Parallel Processors (PMPP) with Numba and CUDA.

# %% [markdown]
# ## Posts
#
# - [Ch1 : Introduction](01_ch1.ipynb) - GPU programming basics and Amdahl's Law.
# - [Ch2 : 1D vector addition](02_ch2.ipynb) - Parallelizing 1D vector addition using CUDA.
# - [Ch3 : Mapping Threads to Multidimensional Data](03_ch3.ipynb) - Parallelizing 2D vector addition using CUDA.

# %% [markdown]
# ## Install

# %%
git clone https://github.com/tripathysagar/PMPP.git
cd PMPP
pip install -e .
